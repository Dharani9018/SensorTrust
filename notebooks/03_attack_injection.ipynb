# %%
import sys
sys.path.append('../src')
from attack_injection import gps_step_drift, lidar_phantom_inject
import pykitti
import open3d as o3d
import numpy as np

data = pykitti.raw(r"C:\Users\disha\Project\datasets\kitti", '2011_09_26', '0009')

# Test GPS step attack
attacked_gps, labels = gps_step_drift(data.oxts, start_frame=50)
print(f"Clean frames: {np.sum(labels==0)}")
print(f"Attacked frames: {np.sum(labels==1)}")
print(f"Original lat at frame 50:  {data.oxts[50].packet.lat:.6f}")
print(f"Attacked lat at frame 50:  {attacked_gps[50]['lat']:.6f}")

# Test LiDAR phantom
scan = data.get_velo(0)
print(f"\nOriginal scan points: {scan.shape[0]}")
attacked_scan = lidar_phantom_inject(scan, n_points=100)
print(f"Attacked scan points: {attacked_scan.shape[0]}")

# Visualise the attacked scan
pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(attacked_scan[:, :3])
o3d.visualization.draw_geometries([pcd])
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       4 import pykitti
#       5 import open3d as o3d
#       6 import numpy as np
#       7
# ----> 8 data = pykitti.raw(r"C:\Users\disha\Project\datasets\kitti", '2011_09_26', '0009')
#       9
#      10 # Test GPS step attack
#      11 attacked_gps, labels = gps_step_drift(data.oxts, start_frame=50)
#
# File ~\SensorTrust\sensor-trust-env312\Lib\site-packages\pykitti\raw.py:34, in raw.__init__(self, base_path, date, drive, **kwargs)
#      31 self._get_file_lists()
#      33 # Pre-load data that isn't returned as a generator
# ---> 34 self._load_calib()
#      35 self._load_timestamps()
#      36 self._load_oxts()
#
# ...
